# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/PPG/Projekt/BIOGRID-ALL-4.4.243.tab3.txt', sep='\t', dtype={1: str, 2: str, 18: str})

# %%
df.shape
# Out:
# (2732721, 31)

# %%
columns_to_remove = ['Ontology Term IDs', 'Ontology Term Names', 'Ontology Term Categories', 'Ontology Term Qualifier IDs', 'Ontology Term Qualifier Names', 'Ontology Term Types']
df = df.drop(columns=columns_to_remove)

df = df.dropna()

df.head()
# Out:
#    #BioGRID Interaction ID Entrez Gene Interactor A Entrez Gene Interactor B  \
# 0                      103                     6416                     2318
# 1                      117                    84665                       88
# 2                      183                       90                     2339
# 3                      278                     2624                     5371
# 4                      418                     6118                     6774
#
#    BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 0                   112315                   108607
# 1                   124185                   106603
# 2                   106605                   108625
# 3                   108894                   111384
# 4                   112038                   112651
#
#   Systematic Name Interactor A Systematic Name Interactor B  \
# 0                            -                            -
# 1                            -                            -
# 2                            -                            -
# 3                            -                            -
# 4                  RP4-547C9.3                            -
#
#   Official Symbol Interactor A Official Symbol Interactor B  \
# 0                       MAP2K4                         FLNC
# 1                         MYPN                        ACTN2
# 2                        ACVR1                         FNTA
# 3                        GATA2                          PML
# 4                         RPA2                        STAT3
#
#                                Synonyms Interactor A  ... Tags  \
# 0  JNKK|JNKK1|MAPKK4|MEK4|MKK4|PRKMK4|SAPKK-1|SAP...  ...    -
# 1                             CMD1DD|CMH22|MYOP|RCM4  ...    -
# 2            ACTRI|ACVR1A|ACVRLK2|ALK2|FOP|SKR1|TSRI  ...    -
# 3                           DCML|IMD21|MONOMAC|NFE1B  ...    -
# 4                      REPA2|RP-A p32|RP-A p34|RPA32  ...    -
#
#   Source Database SWISS-PROT Accessions Interactor A  \
# 0         BIOGRID                             P45985
# 1         BIOGRID                             Q86TC9
# 2         BIOGRID                             Q04771
# 3         BIOGRID                             P23769
# 4         BIOGRID                             P15927
#
#   TREMBL Accessions Interactor A  \
# 0                              -
# 1                     A0A087WX60
# 2                         D3DPA4
# 3                              -
# 4                         B4DUL2
#
#                       REFSEQ Accessions Interactor A  \
# 0                             NP_003001|NP_001268364
# 1                NP_001243197|NP_001243196|NP_115967
# 2                             NP_001104537|NP_001096
# 3                NP_001139134|NP_116027|NP_001139133
# 4  NP_001342057|NP_002937|NP_001284487|NP_0013420...
#
#    SWISS-PROT Accessions Interactor B  TREMBL Accessions Interactor B  \
# 0                              Q14315                          Q59H94
# 1                              P35609                   Q59FD9|F6THM6
# 2                              P49354                               -
# 3                              P29590                               -
# 4                              P40763                               -
#
#                       REFSEQ Accessions Interactor B  \
# 0                             NP_001120959|NP_001449
# 1                NP_001094|NP_001265272|NP_001265273
# 2                                          NP_002018
# 3  NP_150250|NP_150253|NP_150252|NP_150247|NP_150...
# 4  NP_644805|NP_003141|NP_001356447|NP_001356443|...
#
#   Organism Name Interactor A Organism Name Interactor B
# 0               Homo sapiens               Homo sapiens
# 1               Homo sapiens               Homo sapiens
# 2               Homo sapiens               Homo sapiens
# 3               Homo sapiens               Homo sapiens
# 4               Homo sapiens               Homo sapiens
#
# [5 rows x 31 columns]

# %%
filtered_df = df[(df['Organism Name Interactor A'].str.contains('Human Immunodeficiency Virus 1')) | (df['Organism Name Interactor B'].str.contains('Human Immunodeficiency Virus 1'))]

# %%
filtered_df.shape
# Out:
# (2555, 31)

# %%
import networkx as nx

# %%
import networkx as nx

hiv_human_interactions = filtered_df[
    (
        (filtered_df['Organism Name Interactor A'] == 'Human Immunodeficiency Virus 1') &
        (filtered_df['Organism Name Interactor B'] == 'Homo sapiens')
    ) | (
        (filtered_df['Organism Name Interactor A'] == 'Homo sapiens') &
        (filtered_df['Organism Name Interactor B'] == 'Human Immunodeficiency Virus 1')
    )
]

if hiv_human_interactions.empty:
    print("Error: The dataframe for HIV-Human interactions is empty. Cannot create graph.")
else:
    graph = nx.from_pandas_edgelist(
        hiv_human_interactions,
        'Official Symbol Interactor A',
        'Official Symbol Interactor B',
        create_using=nx.Graph()
    )

# %%
graph.remove_nodes_from(list(nx.isolates(graph)))

# %%
graph.number_of_nodes()
# Out:
# 1430

# %%
import requests
import json

DGRAPH_URL = "https://nameless-brook-700075.eu-central-1.aws.cloud.dgraph.io"
API_KEY = DGRAPH

HEADERS = {
    "Content-Type": "application/json",
    "X-Auth-Token": API_KEY
}

schema = """
name: string @index(exact, trigram) .
interacts_with: [uid] @reverse .
type Protein {
  name
  interacts_with
}
"""

res = requests.post(f"{DGRAPH_URL}/alter", json={"schema": schema}, headers=HEADERS)
print("Schema status:", res.status_code, res.text)
# Out:
# Schema status: 200 {"data":{"code":"Success","message":"Done"}}

# %%
uid_map = {node: f"_:{node}" for node in graph.nodes()}

nodes = [{"uid": uid_map[n], "name": n, "dgraph.type": "Protein"} for n in graph.nodes()]

edges = []
for src, dst in graph.edges():
    edges.append({
        "uid": uid_map[src],
        "interacts_with": [{"uid": uid_map[dst]}]
    })

mutation_data = {"set": nodes + edges}
print("Number of nodes:", len(nodes), "Number of relations:", len(edges))

res = requests.post(f"{DGRAPH_URL}/mutate?commitNow=true", json=mutation_data, headers=HEADERS)
print("Loading data:", res.status_code, res.text)
# Out:
# Number of nodes: 1430 Number of relations: 1708
# Loading data: 200 {"data":{"code":"Success","message":"Done","queries":null,"uids":{"AATF":"0x1a53c19b12","ABCB10":"0x1a53c19f76","ABCD3":"0x1a53c19ea9","ABCE1":"0x1a53c19af9","ABCF1":"0x1a53c19d6c","ACACA":"0x1a53c19a8f","ACACB":"0x1a53c19a89","ACBD3":"0x1a53c19aa2","ACBD5":"0x1a53c19f47","ACIN1":"0x1a53c19cfc","ACOT8":"0x1a53c19e0b","ACSL3":"0x1a53c19c67","ACTA1":"0x1a53c19e06","ACTB":"0x1a53c19b3b","ACTG1":"0x1a53c19bf6","ACTL6A":"0x1a53c19e75","ADAR":"0x1a53c19bbe","ADD1":"0x1a53c19ce0","AFF1":"0x1a53c19e02","AFF4":"0x1a53c19ad3","AGFG1":"0x1a53c19fc6","AGO2":"0x1a53c19b8a","AGPS":"0x1a53c19fbd","AHCTF1":"0x1a53c19bfb","AHCY":"0x1a53c19d85","AHCYL1":"0x1a53c19bf3","AHCYL2":"0x1a53c19d36","AHNAK":"0x1a53c19d03","AICDA":"0x1a53c19c42","AIMP1":"0x1a53c19b2d","AIMP2":"0x1a53c19e4e","AKAP11":"0x1a53c19b36","AKAP8L":"0x1a53c19d5e","AKAP9":"0x1a53c19aac","AKT2":"0x1a53c19efb","ALDOA":"0x1a53c19d30","ALMS1":"0x1a53c19ba7","AMBRA1":"0x1a53c19d47","AMOT":"0x1a53c19ac5","ANAPC1":"0x1a53c19c2b","ANAPC2":"0x1a53c19c53","ANAPC5":"0x1a53c19ad6","ANAPC7":"0x1a53c19cf7","ANGEL2":"0x1a53c19dbb","ANKHD1":"0x1a53c19eaf","ANKRD13A":"0x1a53c19ba8","ANKRD17":"0x1a53c19bb6","ANKRD28":"0x1a53c19dc8","ANP32A":"0x1a53c19d19","ANP32B":"0x1a53c19de2","ANP32C":"0x1a53c19df8","ANP32E":"0x1a53c19aba","ANXA2":"0x1a53c19e76","AP1G1":"0x1a53c19ec1","AP1M1":"0x1a53c19eed","AP2M1":"0x1a53c19cc7","AP3B1":"0x1a53c19f0b","AP3M1":"0x1a53c19d91","APC":"0x1a53c19bfd","APEX1":"0x1a53c19da1","APOBEC3C":"0x1a53c19c66","APOBEC3F":"0x1a53c19c20","APOBEC3G":"0x1a53c19cf6","APP":"0x1a53c19be3","ARF1":"0x1a53c19c08","ARFGEF1":"0x1a53c19f60","ARFGEF2":"0x1a53c19eef","ARHGEF12":"0x1a53c19dee","ARHGEF6":"0x1a53c19d70","ARHGEF7":"0x1a53c19c79","ARID1A":"0x1a53c19d31","ARID3B":"0x1a53c19c5e","ARMC5":"0x1a53c19fc1","ARRB2":"0x1a53c19cda","ASB6":"0x1a53c19c1a","ATAD1":"0x1a53c19b09","ATAD3A":"0x1a53c19eaa","ATAD3B":"0x1a53c19d1a","ATAD5":"0x1a53c19de5","ATG2B":"0x1a53c19e7f","ATG3":"0x1a53c19ca9","ATL3":"0x1a53c19c12","ATP13A2":"0x1a53c19ef4","ATP1A1":"0x1a53c19d25","ATP2A2":"0x1a53c19bd1","ATP2A3":"0x1a53c19df0","ATP2B1":"0x1a53c19a74","ATP5B":"0x1a53c19d73","ATP5D":"0x1a53c19f0e","ATP5F1":"0x1a53c19ad2","ATP5H":"0x1a53c19c1d","ATP5J":"0x1a53c19afb","ATP5O":"0x1a53c19dad","ATP6AP1":"0x1a53c19f84","ATRAID":"0x1a53c19cfa","ATRX":"0x1a53c19bec","ATXN10":"0x1a53c19d98","ATXN2L":"0x1a53c19edf","ATXN3":"0x1a53c19cdf","B4GAT1":"0x1a53c19c17","BAG6":"0x1a53c19fc4","BAZ1B":"0x1a53c19a83","BCAP31":"0x1a53c19b68","BCL11B":"0x1a53c19e65","BCL2":"0x1a53c19a9f","BCLAF1":"0x1a53c19dc4","BCOR":"0x1a53c19cc1","BCORL1":"0x1a53c19ae7","BICD2":"0x1a53c19c93","BRCA1":"0x1a53c19e7e","BRD2":"0x1a53c19e9b","BRD3":"0x1a53c19d46","BRD4":"0x1a53c19b44","BRIX1":"0x1a53c19f59","BROX":"0x1a53c19bf0","BST2":"0x1a53c19b1d","BTAF1":"0x1a53c19c60","BTF3":"0x1a53c19ba1","BTRC":"0x1a53c19bce","BUB1":"0x1a53c19ba4","BZW2":"0x1a53c19b3c","C11orf49":"0x1a53c19fb3","C11orf58":"0x1a53c19e11","C14orf166":"0x1a53c19f10","C15orf57":"0x1a53c19caf","C19orf43":"0x1a53c19dd1","C1QBP":"0x1a53c19ad1","C20orf24":"0x1a53c19e3b","C2orf44":"0x1a53c19d39","C2orf49":"0x1a53c19df1","CALCOCO2":"0x1a53c19f19","CALM1":"0x1a53c19a81","CALML5":"0x1a53c19dfc","CALR":"0x1a53c19fc9","CALU":"0x1a53c19c87","CAMSAP1":"0x1a53c19c7c","CAND1":"0x1a53c19d89","CAND2":"0x1a53c19d28","CANX":"0x1a53c19e1a","CAPN1":"0x1a53c19c38","CAPRIN1":"0x1a53c19b6b","CARM1":"0x1a53c19a66","CASC3":"0x1a53c19cf0","CASC5":"0x1a53c19f1a","CBFB":"0x1a53c19fc8","CBX4":"0x1a53c19bc2","CCAR2":"0x1a53c19d63","CCDC137":"0x1a53c19be0","CCDC138":"0x1a53c19abc","CCDC14":"0x1a53c19cd5","CCDC47":"0x1a53c19e83","CCNB2":"0x1a53c19b7f","CCNC":"0x1a53c19eb8","CCNH":"0x1a53c19f8c","CCNO":"0x1a53c19f49","CCNT1":"0x1a53c19e2d","CCNT2":"0x1a53c19ee7","CCT8":"0x1a53c19c3b","CD247":"0x1a53c19bb2","CD2AP":"0x1a53c19c5d","CD320":"0x1a53c19eae","CD4":"0x1a53c19ef3","CD59":"0x1a53c19d51","CD63":"0x1a53c19c90","CD74":"0x1a53c19b87","CD81":"0x1a53c19bcc","CDC23":"0x1a53c19e90","CDC27":"0x1a53c19d ...

# %%
query = """
{
  tat(func: eq(name, "tat")) {
    name
    interacts_with {
      name
    }
  }
}
"""

res = requests.post(f"{DGRAPH_URL}/query", data=json.dumps({"query": query}), headers=HEADERS)
print("Result", json.dumps(res.json(), indent=2))
# Out:
# Result {
#   "data": {
#     "tat": [
#       {
#         "name": "tat",
#         "interacts_with": [
#           {
#             "name": "PURA"
#           },
#           {
#             "name": "TAF15"
#           },
#           {
#             "name": "NCAPD2"
#           },
#           {
#             "name": "PSMA3"
#           },
#           {
#             "name": "WDR5"
#           },
#           {
#             "name": "TRRAP"
#           },
#           {
#             "name": "SQSTM1"
#           },
#           {
#             "name": "MEAF6"
#           },
#           {
#             "name": "ERCC3"
#           },
#           {
#             "name": "MBD3"
#           },
#           {
#             "name": "BAZ1B"
#           },
#           {
#             "name": "CDK9"
#           },
#           {
#             "name": "SRRM2"
#           },
#           {
#             "name": "TRIM32"
#           },
#           {
#             "name": "SMARCA2"
#           },
#           {
#             "name": "LUC7L2"
#           },
#           {
#             "name": "MYH9"
#           },
#           {
#             "name": "YY1"
#           },
#           {
#             "name": "EHMT2"
#           },
#           {
#             "name": "NAP1L4"
#           },
#           {
#             "name": "SMC2"
#           },
#           {
#             "name": "ZFP91"
#           },
#           {
#             "name": "SUV39H1"
#           },
#           {
#             "name": "KCNA3"
#           },
#           {
#             "name": "XPO1"
#           },
#           {
#             "name": "PDS5A"
#           },
#           {
#             "name": "CDK8"
#           },
#           {
#             "name": "HIST1H2BJ"
#           },
#           {
#             "name": "NCAPH"
#           },
#           {
#             "name": "C1QBP"
#           },
#           {
#             "name": "AFF4"
#           },
#           {
#             "name": "HIST1H2BL"
#           },
#           {
#             "name": "N4BP1"
#           },
#           {
#             "name": "RBM39"
#           },
#           {
#             "name": "GATAD2B"
#           },
#           {
#             "name": "EIF3B"
#           },
#           {
#             "name": "HNRNPF"
#           },
#           {
#             "name": "NOP56"
#           },
#           {
#             "name": "RUNX1"
#           },
#           {
#             "name": "PSMB3"
#           },
#           {
#             "name": "CREBBP"
#           },
#           {
#             "name": "AATF"
#           },
#           {
#             "name": "RBM14"
#           },
#           {
#             "name": "MATR3"
#           },
#           {
#             "name": "PHB"
#           },
#           {
#             "name": "KIF22"
#           },
#           {
#             "name": "MTA2"
#           },
#           {
#             "name": "ACTB"
#           },
#           {
#             "name": "BZW2"
#           },
#           {
#             "name": "GTPBP4"
#           },
#           {
#             "name": "DYNC1LI1"
#           },
#           {
#             "name": "HIST2H2BE"
#           },
#           {
#             "name": "NUMA1"
#           },
#           {
#             "name": "UBTF"
#           },
#           {
#             "name": "UHRF1"
#           },
#           {
#             "name": "MDFIC"
#           },
#           {
#             "name": "SETMAR"
#           },
#           {
#             "name": "SUPT5H"
#           },
#           {
#             "name": "UBE2O"
#           },
#           {
#             "name": "SATB1"
#           },
#           {
#             "name": "DHX30"
#           },
#           {
#             "name": "GTF2H1"
#           },
#           {
#             "name": "POLR2E"
#           },
#           {
#             "name": "TBP"
#           },
#           {
#             "name": "CCNB2"
#           },
#           {
#             "name": "PSMB10"
#           },
#           {
#             "name": "FBL"
#           },
#           {
#             "name": "IKZF1"
#           },
#           {
#             "name": "GTF2B"
#           },
#           {
#             "name": "RBBP6"
#           },
#           {
#             "name": "NCL"
#           },
#           {
#             "name": "HNRNPD"
#           },
#           {
#             "name": "GTF3C5"
#           },
#           {
#             "name": "PNN"
#           },
#           {
#             "name": "H2AFV"
#           },
#           {
#             "name": "RUVBL1"
#           },
#           {
#             "name": "ADAR"
#           },
#           {
#             "name": "NFKB1"
#           },
#           {
#             "name": "CBX4"
#           },
#           {
#             "name": "MBD2"
#           },
#           {
#             "name": "PSMB6"
#           },
#           {
#             "name": "PBRM1"
#           },
#           {
#             "name": "ORC4"
#           },
#           {
#             "name": "HEXIM1"
#           },
#           {
#             "name": "CDK1"
#           },
#           {
#             "name": "PJA2"
#           },
#           {
#             "name": "HIST1H4G"
#           },
#           {
#             "name": "SMARCB1"
#           },
#           {
#             "name": "PDS5B"
#           },
#           {
#             "name": "NEK7"
#           },
#           {
#             "name": "ILF2"
#           },
#           {
#             "name": "AHCYL1"
#           },
#           {
#             "name": "DDX21"
#           },
#           {
#             "name": "AHCTF1"
#           },
#           {
#             "name": "EEF1D"
#           },
#           {
#             "name": "DDX3X"
#           },
#           {
#             "name": "SMC4"
#           },
#           {
#             "name": "KPNA2"
#           },
#           {
#             "name": "GTF2E2"
#           },
#           {
#             "name": "CEBPB"
#           },
#           {
#             "name": "H2AFX"
#           },
#           {
#             "name": "LUC7L3"
#           },
#           {
#             "name": "GCN1L1"
#           },
#           {
#             "name": "ZNF638"
#           },
#           {
#             "name": "IRF1"
#           },
#           {
#             "name": "POLR2H"
#           },
#           {
#             "name": "SENP3"
#           },
#           {
#             "name": "EDC4"
#           },
#           {
#             "name": "ZNF512"
#           },
#           {
#             "name": "RFC1"
#           },
#           {
#             "name": "WRN"
#           },
#           {
#             "name": "BTAF1"
#           },
#           {
#             "name": "PABPC1"
#           },
#           {
#             "name": "DDX5"
#           },
#           {
#             "name": "SETDB2"
#           },
#           {
#             "name": "UTP6"
#           },
#           {
#             "name": "PPP1CA"
#           },
#           {
#             "name": "HDAC2"
#           },
#           {
#             "name": "SMC3"
#           },
#           {
#             "name": "TADA2A"
#           },
#           {
#             "name": "TBL3"
#           },
#           {
#             "name": "RNF213"
#           },
#           {
#             "name": "GATAD2A"
#           },
#           {
#             "name": "HIST1H2BA"
#           },
#           {
#             "name": "PSMC1"
#           },
#           {
#             "name": "HIST1H2AH"
#           },
#           {
#             "name": "TUFM"
#           },
#           {
#             "name": "MYEF2"
#           },
#           {
#             "name": "KPNB1"
#           },
#           {
#             "name": "ZNF579"
#           },
#           {
#             "name": "ATG3"
#           },
#           {
#             "name": "SOX4"
#           },
#           {
#             "name": "RBM8A"
#           },
#           {
#             "name": "H2AFZ"
#           },
#           {
#             "name": "SMARCC1"
#           },
#           {
#             "name": "FBXO3"
#           },
#           {
#             "name": "SPEN"
#           },
#           {
#             "name": "PRKCA"
#           },
#           {
#             "name": "SAP18"
#           },
#           {
#             "name": "DNTTIP2"
#           },
#           {
#             "name": "SETDB1"
#           },
#           {
#             "name": "TAAR1"
#           },
#           {
#             "name": "PSMB1"
#           },
#           {
#             "name": "RBM17"
#           },
#           {
#             "name": "GTF2F1"
#           },
#           {
#             "name": "DCAF16"
#           },
#           {
#             "name": "RFC2"
#           },
#           {
#             "name": "EMD"
#           },
#           {
#             "name": "HP1BP3"
#           },
#           {
#             "name": "EIF3A"
#           },
#           {
#             "name": "PSMA4"
#           },
#           {
#             "name": "SIN3A"
#           },
#           {
#             "name": "TARBP2"
#           },
#           {
#             "name": "ANAPC7"
#           },
#           {
#             "name": "ACIN1"
#           },
#           {
#             "name": "WHSC1"
#           },
#           {
#             "name": "DMAP1"
#           },
#           {
#             "name": "DHX15"
#           },
#           {
#             "name": "SNRNP200"
#           },
#           {
#             "name": "NUP98"
#           },
#           {
#             "name": "EIF2AK2"
#           },
#           {
#             "name": "TRIM28"
#           },
#           {
#             "name": "GIMAP1"
#           },
#           {
#             "name": "RBBP4"
#           },
#           {
#             "name": "RNF6"
#           },
#           {
#             "name": "DDX19B"
#           },
#           {
#             "name": "ARID1A"
#           },
#           {
#             "name": "PES1"
#           },
#           {
#             "name": "AHCYL2"
#           },
#           {
#             "name": "KMT2A"
#           },
#           {
#             "name": "MNAT1"
#           },
#           {
#             "name": "POLR2F"
#           },
#           {
#             "name": "HNRNPM"
#           },
#           {
#             "name": "BRD3"
#           },
#           {
#             "name": "MTA3"
#           },
#           {
#             "name": "PSMB7"
#           },
#           {
#             "name": "LARP7"
#           },
#           {
#             "name": "YBX1"
#           },
#           {
#             "name": "SIRT6"
#           },
#           {
#             "name": "HIST1H2BM"
#           },
#           {
#             "name": "MAP1LC3A"
#           },
#           {
#             "name": "DIMT1"
#           },
#           {
#             "name": "FAM98A"
#           },
#           {
#             "name": "KAT2B"
#           },
#           {
#             "name": "POLR2A"
#           },
#           {
#             "name": "POLR2D"
#           },
#           {
#             "name": "PSMA6"
#           },
#           {
#             "name": "LMNB1"
#           },
#           {
#             "name": "CAND1"
#           },
#           {
#             "name": "SMARCA5"
#           },
#           {
#             "name": "TOR1AIP1"
#           },
#           {
#             "name": "PHB2"
#           },
#           {
#             "name": "DDX24"
#           },
#           {
#             "name": "SF1"
#           },
#           {
#             "name": "ILF3"
#           },
#           {
#             "name": "NUP153"
#           },
#           {
#             "name": "GNL3"
#           },
#           {
#             "name": "PLK1"
#           },
#           {
#             "name": "CXCL8"
#           },
#           {
#             "name": "TP53"
#           },
#           {
#             "name": "CISH"
#           },
#           {
#             "name": "PSMB8"
#           },
#           {
#             "name": "THRA"
#           },
#           {
#             "name": "RANBP2"
#           },
#           {
#             "name": "POLR2C"
#           },
#           {
#             "name": "KAT7"
#           },
#           {
#             "name": "GTF2E1"
#           },
#           {
#             "name": "CDCA7"
#           },
#           {
#             "name": "EIF3F"
#           },
#           {
#             "name": "FBN2"
#           },
#           {
#             "name": "HIST3H3"
#           },
#           {
#             "name": "PSMB2"
#           },
#           {
#             "name": "AFF1"
#           },
#           {
#             "name": "PAF1"
#           },
#           {
#             "name": "NUP88"
#           },
#           {
#             "name": "HIST2H2AC"
#           },
#           {
#             "name": "HIST1H2BB"
#           },
#           {
#             "name": "PRPF8"
#           },
#           {
#             "name": "POU2F1"
#           },
#           {
#             "name": "SSRP1"
#           },
#           {
#             "name": "ZBTB7A"
#           },
#           {
#             "name": "H2AFY2"
#           },
#           {
#             "name": "CDCA7L"
#           },
#           {
#             "name": "MLLT1"
#           },
#           {
#             "name": "CCNT1"
#           },
#           {
#             "name": "POLR2L"
#           },
#           {
#             "name": "NCAPG"
#           },
#           {
#             "name": "HIST1H2AA"
#           },
#           {
#             "name": "SMARCC2"
#           },
#           {
#             "name": "SIRT3"
#           },
#           {
#             "name": "SF3B3"
#           },
#           {
#             "name": "USP11"
#           },
#           {
#             "name": "EP300"
#           },
#           {
#             "name": "LBR"
#           },
#           {
#             "name": "POLR2K"
#           },
#           {
#             "name": "THOC1"
#           },
#           {
#             "name": "SIRT2"
#           },
#           {
#             "name": "HIST1H2BH"
#           },
#           {
#             "name": "PSMA7"
#           },
#           {
#             "name": "KAT5"
#           },
#           {
#             "name": "BCL11B"
#           },
#           {
#             "name": "SF3B1"
#           },
#           {
#             "name": "PPM1G"
#           },
#           {
#             "name": "KIAA0020"
#           },
#           {
#             "name": "DDX18"
#           },
#           {
#             "name": "ACTL6A"
#           },
#           {
#             "name": "NCOA2"
#           },
#           {
#             "name": "SUPT4H1"
#           },
#           {
#             "name": "BRCA1"
#           },
#           {
#             "name": "HIC1"
#           },
#           {
#             "name": "MLH1"
#           },
#           {
#             "name": "CDK13"
#           },
#           {
#             "name": "POLR2J"
#           },
#           {
#             "name": "HIST1H2AC"
#           },
#           {
#             "name": "HIST1H2BD"
#           },
#           {
#             "name": "BRD2"
#           },
#           {
#             "name": "OPTN"
#           },
#           {
#             "name": "YEATS4"
#           },
#           {
#             "name": "NUP205"
#           },
#           {
#             "name": "NPM3"
#           },
#           {
#             "name": "MEPCE"
#           },
#           {
#             "name": "HIST1H2BO"
#           },
#           {
#             "name": "RAN"
#           },
#           {
#             "name": "CCNC"
#           },
#           {
#             "name": "EEF1A1"
#           },
#           {
#             "name": "TOP2A"
#           },
#           {
#             "name": "NPM1"
#           },
#           {
#             "name": "MCM6"
#           },
#           {
#             "name": "GNB2L1"
#           },
#           {
#             "name": "HIST1H2AD"
#           },
#           {
#             "name": "KAT2A"
#           },
#           {
#             "name": "SMYD5"
#           },
#           {
#             "name": "STAU2"
#           },
#           {
#             "name": "CDC5L"
#           },
#           {
#             "name": "HDAC1"
#           },
#           {
#             "name": "HIST1H2BK"
#           },
#           {
#             "name": "SSU72"
#           },
#           {
#             "name": "RBBP7"
#           },
#           {
#             "name": "CXXC1"
#           },
#           {
#             "name": "IMMT"
#           },
#           {
#             "name": "TMPO"
#           },
#           {
#             "name": "CDK7"
#           },
#           {
#             "name": "GTF3C4"
#           },
#           {
#             "name": "RPP30"
#           },
#           {
#             "name": "HNRNPH3"
#           },
#           {
#             "name": "CALCOCO2"
#           },
#           {
#             "name": "SIRT1"
#           },
#           {
#             "name": "EP400"
#           },
#           {
#             "name": "HLTF"
#           },
#           {
#             "name": "POLR2I"
#           },
#           {
#             "name": "CDKN2A"
#           },
#           {
#             "name": "HSPA8"
#           },
#           {
#             "name": "H2AFY"
#           },
#           {
#             "name": "SETD1A"
#           },
#           {
#             "name": "DAP3"
#           },
#           {
#             "name": "SUZ12"
#           },
#           {
#             "name": "RANGAP1"
#           },
#           {
#             "name": "POLR2G"
#           },
#           {
#             "name": "NOP2"
#           },
#           {
#             "name": "ZAP70"
#           },
#           {
#             "name": "EIF3E"
#           },
#           {
#             "name": "BRIX1"
#           },
#           {
#             "name": "GABARAP"
#           },
#           {
#             "name": "SP1"
#           },
#           {
#             "name": "PRKDC"
#           },
#           {
#             "name": "TAF5L"
#           },
#           {
#             "name": "MDM2"
#           },
#           {
#             "name": "SUPT16H"
#           },
#           {
#             "name": "MTA1"
#           },
#           {
#             "name": "GTF2F2"
#           },
#           {
#             "name": "MCM7"
#           },
#           {
#             "name": "HIST3H2A"
#           },
#           {
#             "name": "ORC5"
#           },
#           {
#             "name": "NUP85"
#           },
#           {
#             "name": "NOP58"
#           },
#           {
#             "name": "CCNH"
#           },
#           {
#             "name": "HIST2H2AB"
#           },
#           {
#             "name": "PPP1CC"
#           },
#           {
#             "name": "NUP93"
#           },
#           {
#             "name": "NAT10"
#           },
#           {
#             "name": "ERCC2"
#           },
#           {
#             "name": "PAFAH1B1"
#           },
#           {
#             "name": "HIST1H2BN"
#           },
#           {
#             "name": "RUVBL2"
#           },
#           {
#             "name": "DPF2"
#           },
#           {
#             "name": "TP73"
#           },
#           {
#             "name": "POLR2B"
#           },
#           {
#             "name": "HNRNPH1"
#           },
#           {
#             "name": "CHD4"
#           },
#           {
#             "name": "MCM3"
#           },
#           {
#             "name": "PSMB5"
#           },
#           {
#             "name": "SMARCA4"
#           },
#           {
#             "name": "ZNF384"
#           },
#           {
#             "name": "CHD8"
#           }
#         ]
#       }
#     ]
#   },
#   "extensions": {
#     "server_latency": {
#       "parsing_ns": 77441,
#       "processing_ns": 5990686,
#       "encoding_ns": 417606,
#       "assign_timestamp_ns": 1197036,
#       "total_ns": 7845430
#     },
#     "txn": {
#       "start_ts": 399513529,
#       "hash": "d4e260d833a228721dcccf5e7ff6c9c98d892317412c24aa4bcb76334e216788"
#     },
#     "metrics": {
#       "num_uids": {
#         "_total": 336,
#         "interacts_with": 1,
#         "name": 335
#       }
#     }
#   }
# }
